# %% [markdown]
# # hello

# %% [markdown]
# 1. define the role of a Data Analyst in your own words. What value do they bring to an organization?
#    - a data analyst collects,cleans,and interprets data to help organisation make better datA driven decision
